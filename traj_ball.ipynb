# %%
# !git clone https://github.com/EvaShenLu/PointCloud_Render.git
# %cd PointCloud_Render

# !pip install -r requirements.txt

# !wget \
  https://raw.githubusercontent.com/EvaShenLu/PointCloud_Data/main/ours_trajectory_ply_normal_test.zip \
  -O ours_trajectory_ply_normal_test.zip
# !unzip ours_trajectory_ply_normal_test.zip

# %%
# !python traj_vel_renderer.py
# Out:
# Using CUDA GPU (cuda_ad_rgb)
# ...
# Found 220 target file(s) in folder: batch_0
# Output folder: render
# ...
#
# [1/220] (0%) Processing frame 0: frame_0000_b0.ply
# ------------------------------------------------------------
#   Loaded PLY with normal as velocity (nx,ny,nz): shape=(2048, 6)
#   Generating XML... Rendering... Saving... Done!
# ✓ Successfully processed frame 0: frame_0000_b0.ply
#
# [2/220] (0%) Processing frame 1: frame_0001_b0.ply
# ------------------------------------------------------------
#   Loaded PLY with normal as velocity (nx,ny,nz): shape=(2048, 6)
#   Generating XML... Rendering... Saving... Done!
# ✓ Successfully processed frame 1: frame_0001_b0.ply
#
# [3/220] (1%) Processing frame 2: frame_0002_b0.ply
# ------------------------------------------------------------
#   Loaded PLY with normal as velocity (nx,ny,nz): shape=(2048, 6)
#   Generating XML... Rendering... Saving... Done!
# ✓ Successfully processed frame 2: frame_0002_b0.ply
#
# ...

# %%
# %cd render
# !ffmpeg -framerate 24 -pattern_type glob -i "frame_*_b0.png" \
  -c:v libx264 -pix_fmt yuv420p output.mp4
# %cd ..
# Out:
# /content/PointCloud_Render/render
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !zip -r render.zip render
# Out:
#   adding: render/ (stored 0%)
#   adding: render/frame_0065_b0.png (deflated 0%)
#   adding: render/frame_0085_b0.png (deflated 0%)
#   adding: render/frame_0185_b0.png (deflated 0%)
#   adding: render/frame_0142_b0.png (deflated 0%)
#   adding: render/frame_0174_b0.png (deflated 0%)
#   adding: render/frame_0035_b0.png (deflated 0%)
#   adding: render/frame_0163_b0.png (deflated 0%)
#   adding: render/frame_0074_b0.png (deflated 0%)
#   adding: render/frame_0045_b0.png (deflated 0%)
#   adding: render/frame_0158_b0.png (deflated 0%)
#   adding: render/frame_0020_b0.png (deflated 0%)
#   adding: render/frame_0049_b0.png (deflated 0%)
#   adding: render/frame_0187_b0.png (deflated 0%)
#   adding: render/frame_0207_b0.png (deflated 0%)
#   adding: render/frame_0166_b0.png (deflated 0%)
#   adding: render/frame_0219_b0.png (deflated 0%)
#   adding: render/frame_0016_b0.png (deflated 0%)
#   adding: render/frame_0033_b0.png (deflated 0%)
# ...
